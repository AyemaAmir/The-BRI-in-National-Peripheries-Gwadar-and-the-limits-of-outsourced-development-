# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import PatternFill

# File and sheet details
file_name = "Copy of Balochistan PSDP 2013-2022.xlsx"
sheets = [
    "PSDP 2013-14", "PSDP 2014-15", "PSDP 2015-16", "PSDP 2016-17",
    "PSDP 2017-18", "PSDP 2018-19", "PSDP 2019-20", "PSDP 2020-21", "PSDP 2021-22"
]

# Load the workbook and check column names
wb = load_workbook(file_name)
column_names = {}

for sheet in sheets:
    df = pd.read_excel(file_name, sheet_name=sheet)
    column_names[sheet] = list(df.columns)

# Check if all column names are the same
reference_columns = column_names[sheets[0]]
all_columns_same = all(columns == reference_columns for columns in column_names.values())

if not all_columns_same:
    print("Column names differ between sheets:")
    for sheet, columns in column_names.items():
        if columns != reference_columns:
            print(f"{sheet}: {columns}")
else:
    print("All sheets have the same column names.")

# Delete rows with specific colors and save the updated file
color_hex_to_rgb = {
    "#00B0F0": "00B0F0",
    "#FFFF00": "FFFF00"
}

for sheet in sheets:
    ws = wb[sheet]
    rows_to_delete = []

    for row in ws.iter_rows():
        for cell in row:
            if isinstance(cell.fill, PatternFill):
                fill_color = cell.fill.start_color.rgb
                if fill_color in color_hex_to_rgb.values():
                    rows_to_delete.append(row[0].row)
                    break

    # Remove duplicates and sort row indices to delete
    rows_to_delete = sorted(set(rows_to_delete), reverse=True)

    for row_idx in rows_to_delete:
        ws.delete_rows(row_idx)

# Save the updated workbook
output_file = "Updated_Balochistan_PSDP_2013-2022.xlsx"
wb.save(output_file)
print(f"Updated file saved as {output_file}.")
# Out:
# Column names differ between sheets:
# PSDP 2014-15: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2014', 'Throwforward', 'Allocation 2014-15 (Rs.)', 'Allocation 2014-15 (F.A)', 'Allocation 2014-15 (Total)', 'Releases', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14']
# PSDP 2015-16: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2015', 'Throwforward', 'Allocation 2015-16 (Rs.)', 'Allocation 2015-16 (F.A)', 'Allocation 2015-16 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2016-17: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2016', 'Throwforward', 'Allocation 2016-17 (Rs.)', 'Allocation 2016-17 (F.A)', 'Allocation 2016-17 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2017-18: ['Ministry/Division', 'Name of Project', 'Project Category ', 'Project SubCategory ', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2017', 'Throwforward', 'Allocation 2017-18 (F.A)', 'Allocation 2017-18 (RS.)', 'Allocation 2017-18 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2018-19: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2018', 'Throwforward', 'Allocation 2018-19 (F.A)', 'Allocation 2018-19 (RS.)', 'Allocation 2018-19 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2019-20: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2019', 'Throwforward', 'Allocation 2019-20 (F.A)', 'Allocation 2019-20 (RS.)', 'Allocation 2019-20 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2020-21: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2020', 'Throwforward', 'Allocation 2020-21 (F.A)', 'Allocation 2020-21 (RS.)', 'Allocation 2020-21 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2021-22: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2021', 'Throwforward', 'Allocation 2021-22 (F.A)', 'Allocation 2021-22 (RS.)', 'Allocation 2021-22 (Total)', 'Releases (Rupee Component Only)']
# Updated file saved as Updated_Balochistan_PSDP_2013-2022.xlsx.

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import PatternFill

# File and sheet details
file_name = "Copy of Balochistan PSDP 2013-2022.xlsx"
sheets = [
    "PSDP 2013-14", "PSDP 2014-15", "PSDP 2015-16", "PSDP 2016-17",
    "PSDP 2017-18", "PSDP 2018-19", "PSDP 2019-20", "PSDP 2020-21", "PSDP 2021-22"
]

# Load the workbook and check column names
wb = load_workbook(file_name)
column_names = {}

for sheet in sheets:
    df = pd.read_excel(file_name, sheet_name=sheet)
    column_names[sheet] = list(df.columns)

# Check if all column names are the same
reference_columns = column_names[sheets[0]]
all_columns_same = all(columns == reference_columns for columns in column_names.values())

if not all_columns_same:
    print("Column names differ between sheets:")
    for sheet, columns in column_names.items():
        if columns != reference_columns:
            print(f"{sheet}: {columns}")
else:
    print("All sheets have the same column names.")

# Delete rows with specific colors and save the updated file
color_hex_to_rgb = {
    "#00B0F0": "FF00B0F0",  # ARGB format used by openpyxl
    "#FFFF00": "FFFFFF00"
}

for sheet in sheets:
    ws = wb[sheet]
    rows_to_delete = []

    for row in ws.iter_rows():
        for cell in row:
            if cell.fill and cell.fill.start_color:
                fill_color = cell.fill.start_color.rgb
                if fill_color in color_hex_to_rgb.values():
                    rows_to_delete.append(row[0].row)
                    break

    # Remove duplicates and sort row indices to delete
    rows_to_delete = sorted(set(rows_to_delete), reverse=True)

    for row_idx in rows_to_delete:
        ws.delete_rows(row_idx)

# Save the updated workbook
output_file = "Updated_Balochistan_PSDP_2013-2022(1).xlsx"
wb.save(output_file)
print(f"Updated file saved as {output_file}.")
# Out:
# Column names differ between sheets:
# PSDP 2014-15: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2014', 'Throwforward', 'Allocation 2014-15 (Rs.)', 'Allocation 2014-15 (F.A)', 'Allocation 2014-15 (Total)', 'Releases', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14']
# PSDP 2015-16: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2015', 'Throwforward', 'Allocation 2015-16 (Rs.)', 'Allocation 2015-16 (F.A)', 'Allocation 2015-16 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2016-17: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2016', 'Throwforward', 'Allocation 2016-17 (Rs.)', 'Allocation 2016-17 (F.A)', 'Allocation 2016-17 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2017-18: ['Ministry/Division', 'Name of Project', 'Project Category ', 'Project SubCategory ', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2017', 'Throwforward', 'Allocation 2017-18 (F.A)', 'Allocation 2017-18 (RS.)', 'Allocation 2017-18 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2018-19: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2018', 'Throwforward', 'Allocation 2018-19 (F.A)', 'Allocation 2018-19 (RS.)', 'Allocation 2018-19 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2019-20: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2019', 'Throwforward', 'Allocation 2019-20 (F.A)', 'Allocation 2019-20 (RS.)', 'Allocation 2019-20 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2020-21: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2020', 'Throwforward', 'Allocation 2020-21 (F.A)', 'Allocation 2020-21 (RS.)', 'Allocation 2020-21 (Total)', 'Releases (Rupee Component Only)']
# PSDP 2021-22: ['Ministry/Division', 'Name of Project', 'Project Category', 'Project SubCategory', 'Total Cost', 'Foreign Aid (Cost)', 'Expendidture upto June 2021', 'Throwforward', 'Allocation 2021-22 (F.A)', 'Allocation 2021-22 (RS.)', 'Allocation 2021-22 (Total)', 'Releases (Rupee Component Only)']
# Updated file saved as Updated_Balochistan_PSDP_2013-2022(1).xlsx.

# %%
import pandas as pd

# File and sheet details
file_name = "Updated_Balochistan_PSDP_2013-2022 (2).xlsx"
sheets = [
    "PSDP 2013-14", "PSDP 2014-15", "PSDP 2015-16", "PSDP 2016-17",
    "PSDP 2017-18", "PSDP 2018-19", "PSDP 2019-20", "PSDP 2020-21", "PSDP 2021-22"
]

# Load the workbook and check column names
column_names = {}

for sheet in sheets:
    df = pd.read_excel(file_name, sheet_name=sheet)
    column_names[sheet] = list(df.columns)

# Find separate named columns
separate_columns = {}
for sheet, columns in column_names.items():
    separate_columns[sheet] = list(set(columns) - set(column_names[sheets[0]]))

# Print separate named columns for each sheet
for sheet, columns in separate_columns.items():
    if columns:
        print(f"{sheet}: {columns}")
    else:
        print(f"{sheet}: No separate columns found.")
# Out:
# PSDP 2013-14: No separate columns found.
# PSDP 2014-15: ['Allocation 2014-15 (Rs.)', 'Expendidture upto June 2014', 'Allocation 2014-15 (Total)', 'Allocation 2014-15 (F.A)']
# PSDP 2015-16: ['Allocation 2015-16 (F.A)', 'Allocation 2015-16 (Rs.)', 'Allocation 2015-16 (Total)', 'Expendidture upto June 2015']
# PSDP 2016-17: ['Allocation 2016-17 (Total)', 'Allocation 2016-17 (F.A)', 'Expendidture upto June 2016', 'Allocation 2016-17 (Rs.)']
# PSDP 2017-18: ['Allocation 2017-18 (Total)', 'Expendidture upto June 2017', 'Allocation 2017-18 (RS.)', 'Project Category ', 'Allocation 2017-18 (F.A)']
# PSDP 2018-19: ['Allocation 2018-19 (RS.)', 'Expendidture upto June 2018', 'Allocation 2018-19 (Total)', 'Allocation 2018-19 (F.A)']
# PSDP 2019-20: ['Expendidture upto June 2019', 'Allocation 2019-20 (Total)', 'Allocation 2019-20 (F.A)', 'Allocation 2019-20 (RS.)']
# PSDP 2020-21: ['Allocation 2020-21 (Total)', 'Allocation 2020-21 (F.A)', 'Allocation 2020-21 (RS.)', 'Expendidture upto June 2020']
# PSDP 2021-22: ['Allocation 2021-22 (F.A)', 'Allocation 2021-22 (Total)', 'Expendidture upto June 2021', 'Allocation 2021-22 (RS.)']

# %%
import pandas as pd
from openpyxl import load_workbook

# Load the Excel file
file_path = "Updated_Balochistan_PSDP_2013-2022 (2).xlsx"
sheets_to_process = [
    "PSDP 2013-14", "PSDP 2014-15", "PSDP 2015-16",
    "PSDP 2016-17", "PSDP 2017-18", "PSDP 2018-19",
    "PSDP 2019-20", "PSDP 2020-21", "PSDP 2021-22"
]

# Initialize an empty list to hold all data
master_data = []

# Project ID counter
project_id_counter = 1

# Process each sheet
for sheet in sheets_to_process:
    # Load the sheet into a DataFrame
    df = pd.read_excel(file_path, sheet_name=sheet)

    # Normalize column names
    df.columns = df.columns.str.strip()
    df.columns = df.columns.str.replace("\s+", " ", regex=True)
    df.columns = df.columns.str.lower()

    # Check if the required columns exist
    required_columns = ["name of project", "ministry/division", "project category", "project subcategory"]
    if not all(col in df.columns for col in required_columns):
        print(f"Required columns missing in {sheet}. Skipping this sheet.")
        continue

    # Add additional columns
    fiscal_year = sheet.split()[-1]  # Extract fiscal year from sheet name
    df["fiscal year"] = fiscal_year
    df["project id"] = None
    df["is gwadar"] = None

    # Load the workbook and sheet for cell color extraction
    wb = load_workbook(file_path, data_only=True)
    ws = wb[sheet]

    # Iterate over the rows to assign Project ID and determine Is Gwadar
    for index, row in df.iterrows():
        # Assign unique Project ID
        df.at[index, "project id"] = f"P{project_id_counter:06}"  # Format: P000001
        project_id_counter += 1

        # Check if the row is related to Gwadar by examining the background color
        cell = ws[f"B{index + 2}"]  # Assuming "Name of Project" is in column B
        if cell.fill.start_color.rgb == "FF00B050":  # Green color for Gwadar
            df.at[index, "is gwadar"] = "Yes"
        else:
            df.at[index, "is gwadar"] = "No"

    # Select relevant columns for Master Project Details
    master_data.append(df[[
        "project id", "name of project", "ministry/division",
        "project category", "project subcategory", "fiscal year", "is gwadar"
    ]])

# Combine all data into a single DataFrame
master_project_details = pd.concat(master_data, ignore_index=True)

# Save the DataFrame to a CSV file
output_file = "Project Details.csv"
master_project_details.to_csv(output_file, index=False)

print(f"Project Details saved to {output_file}")
# Out:
# Project Details saved to Project Details.csv

# %%
import pandas as pd

# File path for the Excel file
file_path = "Updated_Balochistan_PSDP_2013-2022 (2).xlsx"

# Sheets to process
sheets_to_process = [
    "PSDP 2013-14", "PSDP 2014-15", "PSDP 2015-16",
    "PSDP 2016-17", "PSDP 2017-18", "PSDP 2018-19",
    "PSDP 2019-20", "PSDP 2020-21", "PSDP 2021-22"
]

# Initialize an empty list to hold all data
master_data = []

# Project ID counter
project_id_counter = 1

# Process each sheet
for sheet in sheets_to_process:
    # Load the sheet into a DataFrame
    df = pd.read_excel(file_path, sheet_name=sheet)

    # Normalize column names
    df.columns = df.columns.str.strip()
    df.columns = df.columns.str.replace("\\s+", " ", regex=True)
    df.columns = df.columns.str.lower()

    # Extract the fiscal year from the sheet name
    fiscal_year = sheet.split()[-1]  # e.g., 2013-14

    # Check if required columns exist
    required_columns = [
        "name of project", "total cost", "foreign aid (cost)",
        f"expenditure upto june {fiscal_year.split('-')[0]}", "throwforward",
        f"allocation {fiscal_year} (rs.)", f"allocation {fiscal_year} (f.a)",
        f"allocation {fiscal_year} (total)", "releases"
    ]

    if not all(col in df.columns for col in required_columns):
        print(f"Required columns missing in {sheet}. Skipping this sheet.")
        continue

    # Rename columns for consistency
    df.rename(columns={
        f"expenditure upto june {fiscal_year.split('-')[0]}": "expenditure upto june",
        f"allocation {fiscal_year} (rs.)": "allocation rs",
        f"allocation {fiscal_year} (f.a)": "allocation fa",
        f"allocation {fiscal_year} (total)": "allocation total"
    }, inplace=True)

    # Add Fiscal Year and Project ID columns
    df["fiscal year"] = fiscal_year
    df["project id"] = [f"P{project_id_counter + i:06}" for i in range(len(df))]
    project_id_counter += len(df)

    # Append relevant columns to master data
    master_data.append(df[[
        "project id", "name of project", "fiscal year", "total cost", "foreign aid (cost)",
        "expenditure upto june", "throwforward", "allocation rs", "allocation fa",
        "allocation total", "releases"
    ]])

# Combine all data into a single DataFrame
final_data = pd.concat(master_data, ignore_index=True)

# Save the combined data to a CSV file
output_file = "Financial_Allocations_By_Year.csv"
final_data.to_csv(output_file, index=False)

print(f"Financial allocations data saved to {output_file}")
# Out:
# Financial allocations data saved to Financial_Allocations_By_Year.csv

# %%
import pandas as pd

# Load the two CSV files
financial_allocations_file = "Financial_Allocations_By_Year.csv"
project_details_file = "Project Details.csv"

financial_df = pd.read_csv(financial_allocations_file)
project_details_df = pd.read_csv(project_details_file)

# Normalize column names for consistency
financial_df.columns = financial_df.columns.str.strip().str.lower()
project_details_df.columns = project_details_df.columns.str.strip().str.lower()

# Merge the two DataFrames on "name of project"
merged_df = pd.merge(
    financial_df, project_details_df,
    on="name of project",
    suffixes=("_financial", "_details")
)

# Check for discrepancies in Project IDs
mismatched_projects = merged_df[merged_df["project id_financial"] != merged_df["project id_details"]]

# Output the mismatched projects, if any
if not mismatched_projects.empty:
    print("Mismatched Project IDs found:")
    print(mismatched_projects[["name of project", "project id_financial", "project id_details"]])
else:
    print("All Project IDs match for the same project names.")
# Out:
# Mismatched Project IDs found:
#                                          name of project project id_financial  \
# 7      Kalat-Quetta-Chaman Section of N-\n25 (247 Km)...              P000007
# 10         Construction of Kolpur Bypass N-65\n(Mastung)              P000009
# 18     Bridge Qamar-ud-Din / Surkach,\nBalochistan (Z...              P000016
# 19     Bridge Qamar-ud-Din / Surkach,\nBalochistan (Z...              P000016
# 21     Capacity Building of Teachers\nTraining Instit...              P000017
# ...                                                  ...                  ...
# 32452       Construction of Winder Dam, District Lasbela              P001674
# 32454  Feasibility Study and Detailed Design of Burj ...              P001675
# 32458  Kachhi Canal Project (Remaining Works) Phase-I...              P001678
# 32460             Naulong Storage Dam Project Jhal Magsi              P001679
# 32462  Provision of Groundwater for Industrial sector...              P001680
#
#       project id_details
# 7                P000493
# 10               P000224
# 18               P000232
# 19               P000385
# 21               P000242
# ...                  ...
# 32452            P001475
# 32454            P001477
# 32458            P001481
# 32460            P000993
# 32462            P001184
#
# [30784 rows x 3 columns]

# %%
import pandas as pd

# Load the data from CSV
file_path = "Financial_Allocations_By_Year.csv"
data = pd.read_csv(file_path)

# Group by 'Total Cost' and filter groups with more than one row
duplicates = data.groupby('Total Cost').filter(lambda x: len(x) > 1)

# Add a column for the count of duplicates within each group
duplicates['Count'] = duplicates.groupby('Total Cost')['Total Cost'].transform('size')

# Display the filtered data in table format with counts
print("Projects with the same Total Cost:\n")
print(duplicates.to_string(index=False))

# Display the total number of duplicate projects
total_duplicates = len(duplicates)
print(f"\nTotal number of projects with duplicate Total Costs: {total_duplicates}")
# Out:
# Projects with the same Total Cost:
#
# Project ID                                                                                                                                                                                                                             Name of Project    Year  Total Cost  Foreign aid (Cost)  Expenditure upto June  Throwforward  Allocation (Rs.)  Allocation (F.A)  Allocation(Total)  Releases  Count
#    P000001                Gwadar  - Turbat - Hoshab Section\n(200 Km) of Gwadar - Ratodero Road (892 Km)  M-8, including Khuzdar - Shahdadkot - Ratodero (143 km) - (Gwadar, Turbat, Khuzdar in Balochistan and Kamber, Shahdadkot & Larkana in Sindh) 2013-14   23168.700               0.000              18735.700      4433.000          3433.000             0.000           3433.000   999.940      4
#    P000008                                                                                                                                            Widening & Improvement of N-85,\nHoshab - Nag - Basima - Surab\nRoad (459 Km) (Khuzdar, Panjgur) 2013-14   22412.500               0.000               6090.000     16322.500          5000.000             0.000           5000.000  1300.000      3
#    P000012                                                                                                                                                                                             New Gwadar International Airport\n(NGIA) (Oman) 2013-14    7675.000               0.000                570.000      7105.000           600.000           200.000            800.000    49.000      2
#    P000013                                                                                                           Construction of Admin Block,\nAccommodation Block & allied\nfacilities at PMSA land at Ormara\n(JNB) , Balochistan (Distt Ormara) 2013-14      39.300               0.000                  0.000        39.300            20.000             0.000             20.000       NaN      2
#    P000016                                                                                                                                                                                          Bridge Qamar-ud-Din / Surkach,\nBalochistan (Zhob) 2013-14     180.000               0.000                 47.600       132.400            50.000             0.000             50.000    20.000      4
#    P000017                                                                                                                             Capacity Building of Teachers\nTraining Institutions & Training of\nElementary Schools Teachers in\nBalochistan 2013-14     588.400               0.000                482.400       106.000           106.000             0.000            106.000    22.922      2
#    P000018                                                                                                                                 Const. of Sibi Rakhni Road via\nMaiwand (Tall - Kohlu) Section km\n24 - 164) (Kohlu Package) (Sibbi\nDistt) 2013-14    4751.600               0.000               2446.200      2305.400           550.000             0.000            550.000   220.000      3
#    P000019                                                                                                               Construction of Fish Landing Jetty &\nAllied Harbor Facilities at Pishukan,\nGwadar (Revised)(Federal Share)\n(Distt. Gwadar) 2013-14     834.800               0.000                502.600       332.200           100.000             0.000            100.000    40.000      3
#    P000020                                                                                                              Construction of Fish Landing Jetty &\nAllied Harbor Facilities at Surbandar,\nEast Bay Gwadar (Federal Share)\n(Distt. Gwadar) 2013-14     890.700               0.000                538.000       352.700           100.000             0.000            100.000    40.000      3
#    P000023                                                                                                                          Construction of Various B/T Road to\nlink Different Villages with Main\nKohlu Town (Kohlu Package) (Distt.\nKohlu) 2013-14     222.200               0.000                144.600        77.700            77.667             0.000             77.667    15.533      3
#    P000024                                                                                                                           Construction of 5 Black Top Roads\nin Districts Mastung, Bolan and\nQuetta (Cost reflects maximum\nfederal share) 2013-14    2000.000               0.000               1375.000       625.000           400.000             0.000            400.000       NaN      3
#    P000025                                                                                                                                                                                                Greater Water Supply Quetta (Main)\n(Quetta) 2013-14   17000.000               0.000              10101.900      6898.100          1500.000             0.000           1500.000   300.000      2
#    P000026                                                                                                                                                                                                                Gwadar Development Authority 2013-14   25000.000               0.000               6778.100     18221.900           600.000             0.000            600.000   240.000      9
#    P000028                                                                                                      Improvement of Sui-Dera Bugti\nRoad and Construction of Black Top\nLinked Road at Dera Bugti (Dera\nBugti Package) (Distt. Dera Bugti) 2013-14     592.000               0.000                208.000       384.000           384.042             0.000            384.042       NaN      4
#    P000032                                                                                                                                                                                                          Kharan Residential College, Kharan 2013-14     300.000               0.000                  0.000       300.000           100.000             0.000            100.000       NaN     34
#    P000033                                                                                                                                                                                                                   132 KV Kohlu Grid Station 2013-14     330.000               0.000                  0.000       330.000            31.616             0.000             31.616    31.616      2
#    P000034                                                                                                                                                                                    Construction of Road in District\nNasirabad / Jaffarabad 2013-14     474.500               0.000                401.700        72.800            72.825             0.000             72.825       NaN      4
#    P000036                                                                                                                                                              Construction of BB/T Road from Sui\nto Uch Field (57 km) (Dera Bugti\nPackage) 2013-14     797.700               0.000                393.600       404.100           200.000             0.000            200.000       NaN      4
#    P000037                                                                   Construction of Black Top Road\nfrom Doli Check Post to Sighari\nRoad 109 Bashha Pur Linking\nKandh Kot and Jani Bari Road 238\nDistrict Dera Bugti (Dera Bugti\nPackage) 2013-14     301.400               0.000                226.000        75.400            75.437             0.000             75.437       NaN      3
#    P000038                                                                                                                             Construction of Black Top Road\nfrom Lehri to Sangsilla Road Phase-I\n(Dera Bugti Package) (Distt. Dera\nBugti) 2013-14     841.500               0.000                164.000       677.500           300.000             0.000            300.000       NaN      4
#    P000039                                                                                              Construction of Black Topped from\nDera Bugti to Pitokh, Habib Rahi,\nVadera Killi Murad, Dera Bugti (Dera\nBugti Package) (Distt. Dera Bugti) 2013-14     335.700               0.000                150.000       185.700           185.690             0.000            185.690       NaN      3
#    P000040                                                                                                                                                                                          Development of University of\nBalochistan, Quetta. 2013-14     971.900               0.000                699.700       272.200           160.000             0.000            160.000    55.000      3
#    P000042                                                                       Master Leading to PhD Scholarships\nProgram (Indigenous and Overseas)\nfor the Students of Balochistan (An\nInitiative of the Aghaz-e-Haqooq-e-\nBalochistan Package) 2013-14    3138.700               0.000                 20.000      3118.700           160.000             0.000            160.000    10.000      3
#    P000043                                                                                                                                                          Provision Of Higher Education\nOpportunities For Students of\nBalochistan and FATA 2013-14     981.500               0.000                468.300       513.200           250.000             0.000            250.000   105.000      4
#    P000044                                                                                                                                                        Repair/ Rehabilitation/ Renovation of\nBuildings, University of Balochistan,\nQuetta 2013-14     221.200               0.000                134.000        87.200            87.166             0.000             87.166    27.433      2
#    P000045                                                                                                                        Strengthening and Development of\nBalochistan University of Information\nTechnology and Management\nSciences, Quetta 2013-14     892.700               0.000                  0.000       892.700           120.000             0.000            120.000    30.000      2
#    P000046                                                                                            Strengthening of labs and faculty of\ncrop & plant Sciences at Lesbela\nUniversity of Agriculture, Water and\nMarine Sciences, Uthal Balochistan 2013-14     384.900               0.000                230.000       154.900           154.921             0.000            154.921    63.250      2
#    P000047                                                                                                                        Development of Infrastructure at\nLasbela University of Agriculture,\nWater and Marine Sciences, Uthal,\nBalochistan 2013-14     974.800               0.000                  0.000       974.800           100.000             0.000            100.000    40.000      4
#    P000048                                                                                                                                                                       Strengthening of University of\nBalochistan, Quetta and its\ncampuses 2013-14     560.000               0.000                  0.000       560.000            10.000             0.000             10.000       NaN      2
#    P000049                                                                                                                                                            Strengthening and Development of\nSardar Bahadur Khan Women\nUniversity, Quetta. 2013-14     806.000               0.000                 80.000       726.000           120.000             0.000            120.000    40.000      4
#    P000050                                                                                                                                                                                                         Establishment university at Loralai 2013-14    1518.800               0.000                 75.000      1443.800           120.000             0.000            120.000    20.000      4
#    P000051                                                                                                          Establishment of Undergraduate\nMarine Science Laboratory at\nLasbela University of Agriculture,\nWater and Marine Sciences, Uthal 2013-14     477.800               0.000                404.300        73.500            73.502             0.000             73.502    15.300      2
#    P000052                                                                                                                                                           Musakhail Taunsa Road (35 KM)\nStrength Road Zhob (Between\nPunjab & Balochistan) 2013-14     505.500               0.000                477.000        28.500            28.501             0.000             28.501     5.700      2
#    P000053                                                                                                                                                                                             Re-Settlement of Christian\nCommunity in Quetta 2013-14     497.400               0.000                262.500       234.900            14.000             0.000             14.000       NaN      3
#    P000054                                                                                                                                                                                              Construction of 30 Men Barracks at\nNAB Quetta 2013-14      21.300               0.000                  0.000        21.300            21.310             0.000             21.310     4.262      3
#    P000055                                                                                                                                        Establishment of Chromite\nBenefication Plant at Muslim Bagh,\nDistrict Qilla Saifullah, Balochistan 2013-14     104.300               0.000                 47.000        57.300            57.345             0.000             57.345    11.469      3
#    P000056                                                                                                                                                          Establishment of Infrastructure in\nQuetta Industrial & Trading Estate\n(Phase-II) 2013-14     174.300               0.000                 60.000       114.300            50.000             0.000             50.000    10.000      4
#    P000057                                                                                                                                                                          Provision of Infrastructure in Quetta\nIndustrial Estate (Phase-V) 2013-14     126.900               0.000                 60.000        66.900            66.930             0.000             66.930    13.386      4
#    P000059                                                                                                                                                                              Caster Oil Solvent Extraction Plant\nat Uthal District Lasbela 2013-14     300.000               0.000                 44.000       256.000            60.000             0.000             60.000    12.000     34
#    P000060                                                                                                                                                                                          Establishment of Bostan Industrial\nEstate Phase-I 2013-14     400.400               0.000                 60.100       340.300            60.000             0.000             60.000    12.000      3
#    P000061                                                                                                                Establishment of Intake & Brine\nDisposal System / Civil Works for\ndesalination plants at Gaddani,\nJiwani & Pasni (Gwadar) 2013-14     287.400               0.000                167.000       120.400            60.000             0.000             60.000    12.000      3
#    P000062                                                                                                                                                                                                                 RBS Ziarat Balochistan PTVC 2013-14      53.900               0.000                 45.400         8.500             8.522             0.000              8.522     1.704      4
#    P000063                                                                                                                                                                                                   Rebroadcast Station, Kharan,\nBalochistan 2013-14      57.000               0.000                 40.400        16.600            16.600             0.000             16.600     3.320      9
#    P000064                                                                                                                                                                                                                       Balochi News Services 2013-14       4.500               0.000                  0.000         4.500             4.500             0.000              4.500     0.900      2
#    P000066                                                                                                                                                  Provision of Quality Education\nOpportunities for Students of\nBalochistan & FATA & 3 PMUs 2013-14     481.400               0.000                380.000       101.300            52.640             0.000             52.640    21.056      3
#    P000073                                                                                                                                                           Purchase of Electro-medical\nEquipment for FC Hospital at Quetta.\n(Distt Quetta) 2013-14     474.500               0.000                150.000       324.500           324.452             0.000            324.452   129.780      4
#    P000076                                                                                                                                                                 Construction of 12 x Border Posts for\nFC Balochistan. (Multiple Districts) 2013-14      57.500               0.000                  0.000        57.500            57.500             0.000             57.500    21.000      3
#    P000078                                                                                                                  Const: of 3 X married officer quarters\nfor Pakistan Coast Guards each at\nBattalion Headquarter Gwadar,\nPasni and Uthal. 2013-14      39.400               0.000                 16.400        23.000            22.973             0.000             22.973    22.973      5
#    P000081                                                                                                                                                                     Establishment of Horticulture\nResearch Institute, Khuzdar\nBalochistan 2013-14      53.400               0.000                 15.000        38.400            15.000             0.000             15.000     6.000      3
#    P000082                                                                                                                                                                        Establishment of Livestock\nResearch Institute, Turbat,\nBalochistan 2013-14      58.700               0.000                 20.000        38.700            20.000             0.000             20.000     8.000      3
#    P000083                                                                                                                                                                 Strengthening of Coastal Agriculture\nResearch Station Bhawani\nBalochistan 2013-14      51.700               0.000                 15.000        36.700            15.000             0.000             15.000     6.000      3
#    P000085                                                                                                                                                               Upgradation of Centre for Nuclear\nMedicine and Radiotherapy\n(CENAR), Quetta 2013-14     823.300               0.000                  0.000       823.300           300.000             0.000            300.000       NaN      2
#    P000086                                                                                                                                                                   Inspector General Development\nProjects, Balochistan (Phase-II)\n(Quetta) 2013-14      78.000               0.000                 31.500        46.500             6.900             0.000              6.900     3.450      4
#    P000089                                                                                                                                                                       Light Engineering Upgradation\nCentre for SMEs in Balochistan,\n(HUB) 2013-14     217.900               0.000                  5.000       212.900            60.000             0.000             60.000    12.000      3
#    P000091                                                                                                                                                                        Construction of residential\naccommodation for Income Tax at\nQuetta 2013-14      41.300               0.000                 27.800        13.500            13.491             0.000             13.491       NaN      3
#    P000096                                                                                                                                                                                            Construction of Office & Labs,\nPSQCA at Quetta. 2013-14      36.800               0.000                  3.000        33.800             5.000             0.000              5.000     1.000      3
#    P000097                                                                                                                                                                Establishment of COMSATS\nInstitute of Information Technology at\nJaffarabad 2013-14     853.500               0.000                 50.000       803.500            50.000             0.000             50.000       NaN      3
#    P000099                                                                                                                                                                                       132 KV Sub Stations at Singhar\nHousing Scheme Gwadar 2013-14     371.000              88.000                190.000       181.000            76.000             0.000             76.000    30.400      2
#    P000100                                                                                                                                                                                                          132 KV T/Line Balozai, Balochistan 2013-14     300.000               0.000                200.000       100.000           100.000             0.000            100.000    40.000     34
#    P000104                                                                                                                                                                               Electrification of Village Dera Bughti\n(Dera Bughti Package) 2013-14     718.000               0.000                604.000       114.000           114.000             0.000            114.000    45.600      8
#    P000105                                                                               Power Distribution Enhancement\nProject (Tranche-I & II) (STG-ELRDOP-\nRehabilitation Capacitor\nInstallation & Energy Efficiency (For\n8 Discos) QESCO (ADB) 2013-14    2050.000            1700.000                608.000      1442.000             0.000           800.000            800.000       NaN      2
#    P000106                                                                                                                                                       Study for Master Plan of 6600 MW\nPakistan Power Park at Gaddani,\nBalochistan (PC-II 2013-14     100.000               0.000                  0.000       100.000           100.000             0.000            100.000   100.000     26
#    P000107                                                                                                                                                    New 220 KV Grid Station at Khuzdar\n/ 220 KV Dadu Khuzdar D/C\nTransmission Line (Japan) 2013-14    8540.000            4160.000               9288.000         0.000             0.000           565.000            565.000       NaN      4
#    P000108                                                                                                                                                  Extension of Pat Feeder Canal for\nutilization of Indus Water in\nBalochistan (Dera Bugti) 2013-14    5769.000               0.000               4449.100      1319.900          1320.000             0.000           1320.000   528.000      2
#    P000110                                                                                                                                      Construction of 100 Delay Action\nDam in Balochistan (Package-II, 26\nSmall Dams) (Multiple Districts) 2013-14    4647.400               0.000                880.000      3767.400           450.000             0.000            450.000   180.000      4
#    P000111                                                                                                                                             Construction of 100 Delay Action\nDams in Balochistan 1st Package 20\nDams (Multiple Districts) 2013-14    2467.700               0.000               2466.900         0.800            50.000             0.000             50.000    20.000      2
#    P000114                                                                                                                                                                         Detailed Engg. Design for Winder\nDam, Lasbela Balochistan (Medium) 2013-14    1695.000               0.000                404.200      1290.800            50.000             0.000             50.000       NaN      2
#    P000115                                                                                                                                                                               Naulong Storage Dam, Jhal Magsi\nBalochistan (Medium) (China) 2013-14   18027.100               0.000               1628.500     16398.600          2300.000           200.000           2500.000   460.000      3
#    P000117                                                                                                                                                                     Rehabilitation / Reconstruction of\nAkra Kaur Dam Balochistan\n(Gwadar) 2013-14     460.000               0.000                 65.000       395.000           186.000             0.000            186.000       NaN      2
#    P000119                                                                                                                                                                            Toiwar / Batozai Storage Dam,\nDistrict Qilla Saifullah (Medium) 2013-14    4344.700               0.000               1739.600      2605.100           500.000             0.000            500.000   200.000      4
#    P000120                                                                                                                                               6 Nos. Flood dispersal Structure\nalong with Conveyance System on\nNari River, District Bolan 2013-14    4912.400               0.000               2643.100      2269.300          1170.000             0.000           1170.000   468.000      3
#    P000121                                                                                                                                                                   Balochistan Effluent Disposal into\nRBOD. (RBOD-III) (Multiple Districts) 2013-14    6536.000               0.000               6050.100       485.900          1000.000             0.000           1000.000       NaN      2
#    P000122                                                                                                                                                        Provision of Groundwater for\nDevelopment of Industrial Sector\nBalochistan (Gwadar) 2013-14     839.300               0.000                110.000       729.300           300.000             0.000            300.000       NaN      4
#    P000123                                                                                                                                                                                  Shore Protection of Pasni Town,\nBalochistan (Distt Pasni) 2013-14     941.000               0.000                250.000       691.000           600.000             0.000            600.000       NaN      5
#    P000125                                                                                                                         Feasibility Study for Water\nResources Dev. with Construction of\nSmall Dams in Balochistan (All over\nBalochistan) 2013-14     315.600               0.000                  0.000       315.600           100.000             0.000            100.000    40.000      2
#    P000126                                                                                                               Rehabilitation of Flood 2010\nDamages (RBOD-III) Jaffarabad,\nNasirabad, (Balochistan)\nJacobabad, Qambar Shahdadkot\n(Sindh) 2013-14     563.800               0.000                250.000       313.800           300.000             0.000            300.000   120.000      2
#    P000127                                                                                                                              Reconstruction & Rehabilitation of\nIrrigation Canal system of Tehsil\nUsta M. & Gandakha District\nJaffarabad 2013-14     100.000               0.000                 80.000        20.000            30.000             0.000             30.000       NaN     26
#    P000222                                                                                                                                                                                                    New Gwadar International Airport\n(NGIA) 2014-15    7675.000               0.000                619.000      7056.000           150.000             0.000            150.000       NaN      2
#    P000225               Gwadar - Turbat - Hoshab Section\n(200 km) of Gwadar - Ratodero\nRoad (892 km) M-8, including\nKhuzdar - Shahdadkot - Ratodero\n(143 km)-(Gwadar, Turbat, Khuzdar\nin Balochistan and Kamber,\nShahdadkot & Larkana in Sindh) 2014-15   23168.700               0.000              20257.100      2911.600          5000.000             0.000           5000.000       NaN      4
#    P000228                                                                                                                                                   Sanan to Aab-e-gum Connecting\nRoad Between Sibbi and Distt.\nKachhi (41Km) (50:50 basis) 2014-15     500.000               0.000                  0.000       500.000           500.000             0.000            500.000       NaN      9
#    P000229                                                                                                                           Construction of Admin Block,\nAccommodation Block and other\nAllied Facilities at PMSA Base\nOrmara (JNB), Gwadar 2014-15      39.300               0.000                 10.000        29.300            15.000             0.000             15.000       NaN      2
#    P000231                                                                                                                                                   Provision of Quality Education\nOpportunities for Students of\nBalochistan, FATA & 3 PMUs 2014-15     481.400               0.000                381.400       100.000            76.000             0.000             76.000       NaN      3
#    P000232                                                                                                                                                                                          Bridge Qamar-ud-Din / Surkach,\nBalochistan (Zhob) 2014-15     180.000               0.000                 97.600        82.400            40.000             0.000             40.000       NaN      4
#    P000233                                                                                                                           Construction of Sibi Rakhni Road via\nMaiwand (Tall - Kohlu) Section km\n24 - 164) (Kohlu Package) (Sibbi\nDistt) 2014-15    4751.600               0.000               2796.200      1955.400          1955.416             0.000           1955.416       NaN      3
#    P000234                                                                                                                           Construction of 5 Black Top Roads\nin Districts Mastung, Bolan and\nQuetta (Cost reflects maximum\nFederal Share) 2014-15    2000.000               0.000               1775.000       225.000           225.000             0.000            225.000       NaN      3
#    P000235                                                                                                                                                          Construction of Flyover at Koyala\nPhattak, Samangli Road, Quetta\n(Distt. Quetta) 2014-15    1499.200               0.000                876.200       623.100            10.000             0.000             10.000       NaN      3
#    P000236                                                                                                                                                                           Construction of Flyover at Sariab\nPhatak, Quetta (Distt. Quetta) 2014-15    1581.300               0.000               1100.600       480.700           300.000             0.000            300.000       NaN      2
#    P000237                                                                                                                                                                                                Greater Water Supply Quetta (Main)\n(Quetta) 2014-15   17000.000               0.000              10022.400      6977.600            50.000             0.000             50.000       NaN      2
#    P000238                                                                                                                                                                                   Construction of Roads in District\nNasirabad / Jaffarabad 2014-15     474.500               0.000                401.700        72.800            72.825             0.000             72.825       NaN      4
#    P000239                                                                                                                         Construction of Various B/T Roads\nto link different Villages with Main\nKohlu Town (Kohlu Package) (Distt.\nKohlu) 2014-15     222.200               0.000                215.800         6.400             6.400             0.000              6.400       NaN      3
#    P000240                                                                                                               Construction of Fish Landing Jetty &\nAllied Harbor Facilities at Pishukan,\nGwadar (Revised)(Federal Share)\n(Distt. Gwadar) 2014-15     834.800               0.000                600.000       234.800           134.752             0.000            134.752    26.950      3
#    P000241                                                                                                              Construction of Fish Landing Jetty &\nAllied Harbor Facilities at Surbandar,\nEast Bay Gwadar (Federal Share)\n(Distt. Gwadar) 2014-15     890.700               0.000                638.000       252.700           152.672             0.000            152.672    30.000      3
#    P000242                                                                                                                             Capacity Building of Teachers\nTraining Institutions & Training of\nElementary Schools Teachers in\nBalochistan 2014-15     588.400               0.000                438.800       149.600            50.000             0.000             50.000       NaN      2
#    P000243                                                                                                                                                               Construction of B/T Road from Sui to\nUch Field (57 km) (Dera Bugti\nPackage) 2014-15     797.700               0.000                447.000       350.800           100.000             0.000            100.000       NaN      4
#    P000244                                                                   Construction of Black Top Road\nfrom Doli Check Post to Sighari\nRoad 109 Bashha Pur Linking\nKandh Kot and Jani Bari Road 238\nDistrict Dera Bugti (Dera Bugti\nPackage) 2014-15     301.400               0.000                256.100        45.300            45.257             0.000             45.257       NaN      3
#    P000245                                                                                                                             Construction of Black Top Road\nfrom Lehri to Sangsilla Road Phase-I\n(Dera Bugti Package) (Distt. Dera\nBugti) 2014-15     841.500               0.000                324.000       517.500           100.000             0.000            100.000       NaN      4
#    P000246                                                                                              Construction of Black Topped from\nDera Bugti to Pitokh, Habib Rahi,\nVadera Killi Murad, Dera Bugti (Dera\nBugti Package) (Distt. Dera Bugti) 2014-15     335.700               0.000                213.700       122.000            72.000             0.000             72.000       NaN      3
#    P000247                                                                                                                                                                                                                Gwadar Development Authority 2014-15   25000.000               0.000               6991.500     18008.600           600.000             0.000            600.000   120.000      9
#    P000248                                                                                                      Improvement of Sui-Dera Bugti\nRoad and Construction of Black Top\nLinked Road at Dera Bugti (Dera\nBugti Package) (Distt. Dera Bugti) 2014-15     592.000               0.000                460.000       132.000           132.000             0.000            132.000       NaN      4
#    P000249                                                                                                                                                                                                   Tubli - Badini Road (Max. Federal\nShare) 2014-15     789.600               0.000                598.600       191.000           191.000             0.000            191.000       NaN      2
#    P000250                                                                                                                               Construction / Upgradation of Dirgi\nShabozai (N-70) to Taunsa (N-55)\nRoad, Balochistan (Federal Share\n60%) 2014-15    4796.000               0.000                  0.000      4796.000           100.000             0.000            100.000       NaN      3
#    P000251                                                                                                                                                                                                         Establishment of University at Sibi 2014-15    1500.000               0.000                  0.000      1500.000            35.000             0.000             35.000       NaN     12
#    P000252                                                                                                                                                                                           Development of University of\nBalochistan, Quetta 2014-15     971.900               0.000                826.700       145.200           145.218             0.000            145.218       NaN      3
#    P000254                                                                                                                                                       Repair/ Rehabilitation/ Renovation of\nBuildings, University of Balochistan,\nQuetta. 2014-15     221.200               0.000                211.200        10.000            10.000             0.000             10.000    10.000      2
#    P000255                                                                                                 Strengthening and Development of\nBalochistan University of Information\nTechnology Engineering and\nManagement Sciences (BUITEMS),\nQuetta 2014-15     892.700               0.000                120.000       772.700           300.000             0.000            300.000   115.000      2
#    P000256                                                                                                                                                          Strengthening and Development of\nSardar Bahadur Khan Women's\nUniversity, Quetta. 2014-15     806.000               0.000                180.000       626.000           190.000             0.000            190.000    40.000      4
#    P000257                                                                                                                                                                                                Establishment of HEC Regional\nCentre Quetta 2014-15     120.000               0.000                  0.000       120.000            10.000             0.000             10.000       NaN      9
#    P000258                                                                                                                                                                           Expansion of University of\nBalochistan, Quetta and its\nCampuses 2014-15     560.000               0.000                  0.000       560.000            15.000             0.000             15.000       NaN      2
#    P000260                                                                                                                                                                                                      Establishment of University at Loralai 2014-15    1518.800               0.000                120.000      1398.800           100.000             0.000            100.000       NaN      4
#    P000261                                                                                                                        Development of Infrastructure at\nLasbela University of Agriculture,\nWater and Marine Sciences, Uthal,\nBalochistan 2014-15     974.800               0.000                 80.000       894.800           200.000             0.000            200.000       NaN      4
#    P000262                                                                                                          Establishment of Undergraduate\nMarine Science Laboratory at\nLasbela University of Agriculture,\nWater and Marine Sciences, Uthal 2014-15     477.800               0.000                437.800        40.000            40.000             0.000             40.000    10.000      2
#    P000264                                                                                                                                                                Establishment of COMSATS\nInstitute of Information Technology at\nJaffarabad 2014-15     853.500               0.000                  0.000       853.500             5.000             0.000              5.000       NaN      3
#    P000265                                                                                                                                                                                                       Establishment of University at Turbat 2014-15    1580.400               0.000                135.000      1445.400           355.000             0.000            355.000   150.000      2
#    P000266                                                                       Master Leading to PhD Scholarships\nProgram (Indigenous and Overseas)\nfor the Students of Balochistan (An\nInitiative of the Aghaz-e-Haqooq-e-\nBalochistan Package) 2014-15    3138.700               0.000                170.000      2968.700           240.739             0.000            240.739    60.000      3
#    P000267                                                                                                                                                          Provision of Higher Education\nOpportunities for Students of\nBalochistan and FATA 2014-15     981.500               0.000                718.200       263.300           120.000             0.000            120.000    55.000      4
#    P000268                                                                                            Strengthening of Labs and Faculty of\nCrop & Plant Sciences at Lesbela\nUniversity of Agriculture, Water and\nMarine Sciences, Uthal Balochistan 2014-15     384.900               0.000                374.900        10.000            10.000             0.000             10.000    10.000      2
#    P000269                                                                                                                                                           Musakhail Taunsa Road (35 KM)\nStrength Road Zhob (Between\nPunjab & Balochistan) 2014-15     505.500               0.000                345.400       160.100           160.140             0.000            160.140       NaN      2
#    P000270                                                                                                                                                                                              Construction of 30 Men Barracks at\nNAB Quetta 2014-15      21.300               0.000                  4.300        17.000            17.000             0.000             17.000       NaN      3
#    P000272                                                                                                                                                                                             Re-Settlement of Christian\nCommunity in Quetta 2014-15     497.400               0.000                211.900       285.500            22.863             0.000             22.863       NaN      3
#    P000273                                                                                                                                                          Establishment of infrastructure in\nQuetta Industrial & Trading Estate\n(Phase-II) 2014-15     174.300               0.000                 62.000       112.300            50.000             0.000             50.000       NaN      4
# ...
#    P001633                                                                                                                                             889     Construction of 132KV Grid Station at Khan Mehterzai with Allied T/Line (50:50) (QESCO) 2021-22     249.770               0.000                100.000       149.770           149.770             0.000            149.770       NaN      3
#    P001634                                                                                                                                                  890     Construction of 132-KV Mashkay G/S with Allied 132-KV Nall- Mashkay T/Line (QESCO) 2021-22    1246.201               0.000                860.017       386.184           386.184             0.000            386.184       NaN      3
#    P001635                                                                                                                                                     891     Construction of 33KV Grid Station in Ghurak Area Nall, District Khuzdar (QESCO) 2021-22     100.000               0.000                 50.000        50.000            50.000             0.000             50.000       NaN     26
#    P001636                                                                                                                                                                       892     Conversion of LT Lines into ABC Works in Khuzdar City (QESCO) 2021-22      27.350               0.000                  7.550        19.800            19.800             0.000             19.800       NaN      3
#    P001637                                                                                                                                                                893     Electrification of Village Dera Bughti (Dera Bughti Package) (QESCO) 2021-22     718.000               0.000                248.000       470.000           200.000             0.000            200.000       NaN      8
#    P001638                                                                                                                             895     Establishment of New Distribution Lines for the Electrification of Villages of District Khuzdar (QESCO) 2021-22     190.000               0.000                 95.000        95.000            95.000             0.000             95.000       NaN      2
#    P001639                                                                                                                             897     Interconnection of Isolated Makran Network at Basima via Nag G/Station from Panjgoor G/Station (QESCO). 2021-22   17421.440               0.000               3059.592     14361.848          5000.000             0.000           5000.000       NaN      3
#    P001640                                                                                                                                                                    898     Provision of 50KV Transformers  and 250 Poles for NA-268 (QESCO) 2021-22     160.000               0.000                 34.000       126.000            20.000             0.000             20.000       NaN      4
#    P001641                                                                                                                                                                                       902     Village Electrification in Hazarganji (QESCO) 2021-22      60.000               0.000                 30.000        30.000            30.000             0.000             30.000       NaN     11
#    P001642                                                                                                                                                                                           903     Village Electrification in NA-266 (QESCO) 2021-22     100.000               0.000                 50.000        50.000            50.000             0.000             50.000       NaN     26
#    P001647                                                                                                                                          918     220-KV Dera Ismail Khan - Zhob Transmission Line alongwith 220- KV Zhob Sub-Station (NTDC) 2021-22    6878.510            3094.000               9463.026     -2584.516           500.000          1500.000           2000.000       NaN      3
#    P001648                                                                                                                                                                                    927     220-KV Mastung G/S along wtih Allied T/Ls (NTDC) 2021-22   14144.000            6046.340                143.479     14000.521          1000.000          1500.000           2500.000       NaN      3
#    P001649                                                                                               947     Construction of New 220 kV Guddu- Sibbi Single Circuit Transmission Line for Improvement of Power Supply System in South Areas (NTDC) 2021-22    8624.240            2978.190               7737.240       887.000           300.000           900.000           1200.000       NaN      2
#    P001650                                                                                                                        948     Consultancy services for Feasibility Study of Solar Water Pumping in Balochistan area (Own Resources) (NTDC) 2021-22     154.400              29.800                 77.000        77.400             0.000             0.000              0.000       NaN      2
#    P001654                                                                                                                                                                                        Construction of Model Custom Collectorate at Gawadar 2021-22    1500.000               0.000                488.200      1011.800           119.709             0.000            119.709       NaN     12
#    P001659                                                                                                                                                                                             Construction of Offices & Labs, PSQCA at Quetta 2021-22      53.730               0.000                 26.481        27.249             5.000             0.000              5.000       NaN      4
#    P001662                                                                                                                                                                         Strengthening of Oceanographic Research Sub Station Gwadar Pakistan 2021-22     200.000               0.000                  0.000       200.000            25.000             0.000             25.000       NaN     15
#    P001664                                                                                                                                                          Construction of 100 Dams in District\nAreas/ Districts of Balochistan (Package-IV) 2021-22   13512.725               0.000                500.000     13012.725           500.000             0.000            500.000       NaN      2
#    P001665                                                                                                                                                                         Construction of 100 Small Dams in Balochistan (Package-III 20 Dams) 2021-22    7829.874               0.000               5551.454      2278.420           500.000             0.000            500.000       NaN      5
#    P001666                                                                                                                                      Construction of 100 Small Dams in Tehsil Dobandi, Gulistan Killa Abd (Total 1591.564 , Prov 541.132 M) 2021-22    1050.432               0.000                988.346        62.086            62.086             0.000             62.086       NaN      2
#    P001667                                                                                                                                                                     Construction of 200 Dams in Killa Abdullah, Gulistan and Dobandi Thesil 2021-22    2937.520               0.000               1570.000      1367.520           800.000             0.000            800.000       NaN      4
#    P001669                                                                                                                                                                                Construction of Delay Action Dam at Zarkhune District Quetta 2021-22     100.000               0.000                 30.000        70.000            70.000             0.000             70.000       NaN     26
#    P001670                                                                                                                                                                                    Construction of Mangi Dam, Quetta, Cost 9334.078 (50:50) 2021-22    4667.039               0.000               3920.760       746.279           100.000             0.000            100.000       NaN      2
#    P001671                                                                                                                                                                   Construction of Mara Tangi Dam District Loralai (Fed:337.5, Prov 112.5 M) 2021-22     450.000               0.000                200.000       250.000            50.000             0.000             50.000       NaN      7
#    P001672                                                                                                                                                                   Construction of Sari Kalah Delay Action Dam in U/C Raskoh District Kharan 2021-22     510.000               0.000                167.000       343.000           343.000             0.000            343.000       NaN      3
#    P001673                                                                                                                                                                                                       Construction of Small Dams in Khuzdar 2021-22    1000.000               0.000                695.050       304.950           304.950             0.000            304.950       NaN     18
#    P001676                                                                                                                                              Garuk Storage Dam District Kharan Cost 10511.19 M including provincial share of Rs. 1011.19 M) 2021-22    9500.000               0.000               4383.357      5116.643           300.000             0.000            300.000       NaN      2
#    P001677                                                                                                                                                                 Kachhi Canal Project (Phase-I) Dera Bugti, Naseerabad, Bolan and Jhal Magsi 2021-22   80352.000               0.000              76577.358      3774.642          1860.000             0.000           1860.000       NaN      6
#    P001678                                                                                                                                                                         Kachhi Canal Project (Remaining Works) Phase-I, District Dera Bugti 2021-22   22921.000               0.000               2000.000     20921.000          2000.000             0.000           2000.000       NaN      2
#    P001679                                                                                                                                                                                                      Naulong Storage Dam Project Jhal Magsi 2021-22   28465.000               0.000                629.435     27835.565           950.000            50.000           1000.000       NaN      2
#    P001680                                                                                                                                                                         Provision of Groundwater for Industrial sector Balochistan (Gwadar) 2021-22     839.294               0.000                410.384       428.910             5.000             0.000              5.000       NaN      4
#    P001681                                                                                                                                                                           Construction of 05 Nos. of Dams in District Loralai (Feasibility) 2021-22      15.000               0.000                  0.000        15.000            15.000             0.000             15.000       NaN      6
#    P001682                                                                                                                                                                       Construction of 06 Nos. Dams in District Zhob & Sherani (Feasibility) 2021-22      15.000               0.000                  0.000        15.000            15.000             0.000             15.000       NaN      6
#    P001683                                                                                                                                                                            Construction of Asreli Storage Dam Sui, Dera Bugti (Feasibility) 2021-22      15.000               0.000                  0.000        15.000            15.000             0.000             15.000       NaN      6
#    P001685                                                                                                                                                                                     Construction of Dinar Dam, Killa Abdullah (Feasibility) 2021-22      15.000               0.000                  0.000        15.000            15.000             0.000             15.000       NaN      6
#    P001690                                                                                                                                                                           Construction of Pharaho Delay Action Dam Dera Bugti (Feasibility) 2021-22      10.000               0.000                  0.000        10.000            10.000             0.000             10.000       NaN      5
#    P001692                                                                                                                                                                               Construction of Small Dams in\nDistricts Ziarat (Feasibility) 2021-22      15.000               0.000                  0.000        15.000            15.000             0.000             15.000       NaN      6
#    P001695                                                                                                                                                              Construction of Talango Pir Koh Area Delay Action Dam Dera Bugti (Feasibility) 2021-22      10.000               0.000                  0.000        10.000            10.000             0.000             10.000       NaN      5
#    P001698                                                                                                                                                               Construction of Tuk Storage Dam Tehsil Wadh in District Khuzdar (Feasibility) 2021-22      15.000               0.000                  0.000        15.000            15.000             0.000             15.000       NaN      6
#    P001700                                                                                                                                                                                 Mapping of All Water Resources in Southern Balochistan (SB) 2021-22     480.000               0.000                  0.000       480.000           223.720             0.000            223.720       NaN      3
#
# Total number of projects with duplicate Total Costs: 1104

# %%
import pandas as pd

# Load the data from CSV
file_path = "Financial_Allocations_By_Year.csv"
data = pd.read_csv(file_path)

# Group by 'Total Cost' and filter groups with more than one row
duplicates = data.groupby('Total Cost').filter(lambda x: len(x) > 1)

# Sort the data for better readability (e.g., by 'Total Cost' and 'Year')
duplicates = duplicates.sort_values(by=['Total Cost', 'Year'])

# Display the first 10 rows of all duplicate groups in table format
print("All duplicate projects (first 10 rows shown for preview):\n")
print(duplicates.head(10).to_string(index=False))

# Count total duplicate groups
duplicate_count = duplicates['Total Cost'].nunique()
print(f"\nTotal unique 'Total Cost' values with duplicates: {duplicate_count}")
# Out:
# All duplicate projects (first 10 rows shown for preview):
#
# Project ID                                                                                                                  Name of Project    Year  Total Cost  Foreign aid (Cost)  Expenditure upto June  Throwforward  Allocation (Rs.)  Allocation (F.A)  Allocation(Total)  Releases
#    P000064                                                                                                            Balochi News Services 2013-14         4.5                 0.0                    0.0           4.5             4.500               0.0              4.500     0.900
#    P001616                                           725     Acquisition of Land for Construction of ANF Police Station at Hub, Balochistan 2021-22         4.5                 0.0                    0.0           4.5             4.500               0.0              4.500       NaN
#    P000808                                                                      Feasibility Study of Babar Kuchh Dam,\nBalochistan (50:50)* 2017-18         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P000809                                                                                                   Feasibility Study of Halak Dam 2017-18         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P000813                                                                               Six Dispersal Structures Zhob River\n(Feasibility) 2017-18         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P001061                                                         Construction of Road from Dalbadin to Ziarat-Balanosh 51Km (Feasibility) 2019-20         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P001063                                                               Construction of Road from Kingri to Musakhel (56 KM) (Feasibility) 2019-20         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P000416                                                        Rehabilitation / Renovation and\nRefurbishment of Federal Lodge-I\nQuetta 2015-16         5.2                 0.0                    1.5           3.7             3.684               0.0              3.684     3.684
#    P000546                                                            Rehabilitation/Renovation &\nRefurbishment of Federal Lodge-I\nQuetta 2016-17         5.2                 0.0                    3.7           1.5             4.092               0.0              4.092       NaN
#    P000458 Construction of Boundary Wall with\nBarbed Wire and Special Repair of\nBuilding including Mosque at\nDirectorate of Hajj, Quetta 2015-16         6.5                 0.0                    0.0           6.5             3.000               0.0              3.000       NaN
#
# Total unique 'Total Cost' values with duplicates: 319

# %%
import pandas as pd

# Load the data from the CSV
file_path = "Financial_Allocations_By_Year.csv"
data = pd.read_csv(file_path)

# Group by 'Total Cost' and filter groups with more than one row
duplicates = data.groupby('Total Cost').filter(lambda x: len(x) > 1)

# Sort the duplicate rows by 'Total Cost' and 'Year'
duplicates_sorted = duplicates.sort_values(by=['Total Cost', 'Year'])

# Save the filtered duplicate projects to a new CSV
output_file_path = "Duplicate_Projects_Sorted.csv"
duplicates_sorted.to_csv(output_file_path, index=False)

# Count the total unique 'Total Cost' values with duplicates
duplicate_count = duplicates_sorted['Total Cost'].nunique()

# Display completion message and count
print(f"Duplicate projects saved to '{output_file_path}'.")
print(f"Total unique 'Total Cost' values with duplicates: {duplicate_count}")

# Optional: Display the first 10 rows of duplicate data for verification
print("\nPreview of the first 10 rows of duplicate projects:")
print(duplicates_sorted.head(10).to_string(index=False))
# Out:
# Duplicate projects saved to 'Duplicate_Projects_Sorted.csv'.
# Total unique 'Total Cost' values with duplicates: 319
#
# Preview of the first 10 rows of duplicate projects:
# Project ID                                                                                                                  Name of Project    Year  Total Cost  Foreign aid (Cost)  Expenditure upto June  Throwforward  Allocation (Rs.)  Allocation (F.A)  Allocation(Total)  Releases
#    P000064                                                                                                            Balochi News Services 2013-14         4.5                 0.0                    0.0           4.5             4.500               0.0              4.500     0.900
#    P001616                                           725     Acquisition of Land for Construction of ANF Police Station at Hub, Balochistan 2021-22         4.5                 0.0                    0.0           4.5             4.500               0.0              4.500       NaN
#    P000808                                                                      Feasibility Study of Babar Kuchh Dam,\nBalochistan (50:50)* 2017-18         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P000809                                                                                                   Feasibility Study of Halak Dam 2017-18         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P000813                                                                               Six Dispersal Structures Zhob River\n(Feasibility) 2017-18         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P001061                                                         Construction of Road from Dalbadin to Ziarat-Balanosh 51Km (Feasibility) 2019-20         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P001063                                                               Construction of Road from Kingri to Musakhel (56 KM) (Feasibility) 2019-20         5.0                 0.0                    0.0           5.0             5.000               0.0              5.000       NaN
#    P000416                                                        Rehabilitation / Renovation and\nRefurbishment of Federal Lodge-I\nQuetta 2015-16         5.2                 0.0                    1.5           3.7             3.684               0.0              3.684     3.684
#    P000546                                                            Rehabilitation/Renovation &\nRefurbishment of Federal Lodge-I\nQuetta 2016-17         5.2                 0.0                    3.7           1.5             4.092               0.0              4.092       NaN
#    P000458 Construction of Boundary Wall with\nBarbed Wire and Special Repair of\nBuilding including Mosque at\nDirectorate of Hajj, Quetta 2015-16         6.5                 0.0                    0.0           6.5             3.000               0.0              3.000       NaN

# %%
import pandas as pd

# Load the data from the CSV
file_path = "Financial_Allocations_By_Year.csv"
data = pd.read_csv(file_path)

# Case 1: Duplicates with the same 'Name of Project'
name_duplicates = data[data.duplicated(subset=['Name of Project'], keep=False)]

# Case 2: Duplicates with the same 'Total Cost'
cost_duplicates = data[data.duplicated(subset=['Total Cost'], keep=False)]

# Case 3: Duplicates with the same 'Name of Project' and 'Total Cost'
both_duplicates = data[data.duplicated(subset=['Name of Project', 'Total Cost'], keep=False)]

# Combine all duplicates and remove exact duplicates from this combined set
all_duplicates = pd.concat([name_duplicates, cost_duplicates, both_duplicates]).drop_duplicates()

# Sort for clarity
all_duplicates_sorted = all_duplicates.sort_values(by=['Name of Project', 'Total Cost', 'Year'])

# Save to a CSV for inspection
output_file_path = "All_Duplicate_Cases_Sorted.csv"
all_duplicates_sorted.to_csv(output_file_path, index=False)

# Display statistics
print(f"Duplicate projects saved to '{output_file_path}'.")
print(f"Total rows in duplicates: {len(all_duplicates_sorted)}")
print(f"Preview of the first 10 rows:")
print(all_duplicates_sorted.head(10).to_string(index=False))
# Out:
# Duplicate projects saved to 'All_Duplicate_Cases_Sorted.csv'.
# Total rows in duplicates: 1354
# Preview of the first 10 rows:
# Project ID                                                                                                                                                                                       Name of Project    Year  Total Cost  Foreign aid (Cost)  Expenditure upto June  Throwforward  Allocation (Rs.)  Allocation (F.A)  Allocation(Total)  Releases
#    P001042                                                                                        Construction of Black Top Road from Lehri to Sangsilla Road Phase-I (Dera Bugti Package) (District Dera Bugti) 2019-20     841.480               0.000                244.000       597.480            49.640               0.0             49.640       NaN
#    P000947 (i) Feasibility Study to connect Gwadar\nwith Karachi through Rail Link\n(Approx:700 Km)\n(ii) Feasibility Study of a Rail Link from\nGwadar to Besima and Besima to\nJacobabad via Khuzdar (1048 Km) 2018-19     135.500               0.000                115.039        20.461            20.461               0.0             20.461       NaN
#    P000456                                     (i) PC-II for Feasibility Study to\nConnect Gwadar with Karachi . (ii)\nFeasibility Study from Gwadar to\nBasima and from Basima to\nJacobabad via Khuzdar (CPEC) 2015-16     138.000               0.000                 30.200       107.800            10.000               0.0             10.000       NaN
#    P000316                                     (i) PC-II for Feasibility Study to\nConnect Gwadar with Karachi . (ii)\nFeasibility Study from Gwadar to\nBesima and from Besima to\nJacobabad via Khuzdar (CPEC) 2014-15     138.000               0.000                  0.000       138.000           100.000               0.0            100.000    20.000
#    P000579                                                                                    (i) PC-II for Feasibility Study to\nConnect Gwadar with Karachi . (ii)\nGwadar to Jacobabad via Basima\nunder CPEC 2016-17     135.500               0.000                 10.000       125.500            80.500               0.0             80.500    80.500
#    P000733                                     (i) PC-II for Feasibility Study to Connect\nGwadar with Karachi .\n(ii) Feasibility Study from Gwadar to\nBesima and from Besima to Jacobabad\nvia Khuzdar (CPEC) 2017-18     135.500               0.000                102.891        32.609            32.609               0.0             32.609       NaN
#    P001504                                                                                                      100     Rehabilitation/Upgradation and Widening of Quetta - Dhadhar Section of N-65 (118.322 km) 2021-22    7115.760               0.000                  0.000      7115.760          1000.000               0.0           1000.000       NaN
#    P000555                                                                                                                                                                         100 KW MW Gwadar, Balochistan 2016-17     139.800               0.000                  0.900       139.000            33.804               0.0             33.804    33.804
#    P000696                                                                                                                                                                         100 KW MW Gwadar, Balochistan 2017-18     139.842              26.312                 34.696       105.146            50.000               0.0             50.000       NaN
#    P000898                                                                                                                                                                          100 KW MW Transmitter Gwadar 2018-19     139.842               0.000                101.913        37.929            15.000               0.0             15.000       NaN

# %%
import pandas as pd

# Load the data from the CSV
file_path = "Financial_Allocations_By_Year.csv"
data = pd.read_csv(file_path)

# Fill NaN values in 'Total Cost' with 0.0
data['Total Cost'] = data['Total Cost'].fillna(0.0)

# Convert 'Total Cost' to integers (remove decimals by truncating)
data['Total Cost (Rounded)'] = data['Total Cost'].apply(lambda x: int(float(x)))

# Case 1: Duplicates with the same 'Name of Project'
name_duplicates = data[data.duplicated(subset=['Name of Project'], keep=False)]

# Case 2: Duplicates with the same rounded 'Total Cost'
cost_duplicates = data[data.duplicated(subset=['Total Cost (Rounded)'], keep=False)]

# Case 3: Duplicates with the same 'Name of Project' and rounded 'Total Cost'
both_duplicates = data[data.duplicated(subset=['Name of Project', 'Total Cost (Rounded)'], keep=False)]

# Combine all duplicates and remove exact duplicates from this combined set
all_duplicates = pd.concat([name_duplicates, cost_duplicates, both_duplicates]).drop_duplicates()

# Sort for clarity
all_duplicates_sorted = all_duplicates.sort_values(by=['Name of Project', 'Total Cost (Rounded)', 'Year'])

# Save to a CSV for inspection
output_file_path = "All_Duplicate_Cases_Sorted7.csv"
all_duplicates_sorted.to_csv(output_file_path, index=False)

# Display statistics
print(f"Duplicate projects saved to '{output_file_path}'.")
print(f"Total rows in duplicates: {len(all_duplicates_sorted)}")
print(f"Preview of the first 10 rows:")
print(all_duplicates_sorted.head(10).to_string(index=False))
# Out:
# Duplicate projects saved to 'All_Duplicate_Cases_Sorted7.csv'.
# Total rows in duplicates: 1508
# Preview of the first 10 rows:
# Project ID                                                                                                                                                                                       Name of Project    Year  Total Cost  Foreign aid (Cost)  Expenditure upto June  Throwforward  Allocation (Rs.)  Allocation (F.A)  Allocation(Total)  Releases  Total Cost (Rounded)
#    P001042                                                                                        Construction of Black Top Road from Lehri to Sangsilla Road Phase-I (Dera Bugti Package) (District Dera Bugti) 2019-20     841.480               0.000                244.000       597.480            49.640               0.0             49.640       NaN                   841
#    P000947 (i) Feasibility Study to connect Gwadar\nwith Karachi through Rail Link\n(Approx:700 Km)\n(ii) Feasibility Study of a Rail Link from\nGwadar to Besima and Besima to\nJacobabad via Khuzdar (1048 Km) 2018-19     135.500               0.000                115.039        20.461            20.461               0.0             20.461       NaN                   135
#    P000456                                     (i) PC-II for Feasibility Study to\nConnect Gwadar with Karachi . (ii)\nFeasibility Study from Gwadar to\nBasima and from Basima to\nJacobabad via Khuzdar (CPEC) 2015-16     138.000               0.000                 30.200       107.800            10.000               0.0             10.000       NaN                   138
#    P000316                                     (i) PC-II for Feasibility Study to\nConnect Gwadar with Karachi . (ii)\nFeasibility Study from Gwadar to\nBesima and from Besima to\nJacobabad via Khuzdar (CPEC) 2014-15     138.000               0.000                  0.000       138.000           100.000               0.0            100.000    20.000                   138
#    P000579                                                                                    (i) PC-II for Feasibility Study to\nConnect Gwadar with Karachi . (ii)\nGwadar to Jacobabad via Basima\nunder CPEC 2016-17     135.500               0.000                 10.000       125.500            80.500               0.0             80.500    80.500                   135
#    P000733                                     (i) PC-II for Feasibility Study to Connect\nGwadar with Karachi .\n(ii) Feasibility Study from Gwadar to\nBesima and from Besima to Jacobabad\nvia Khuzdar (CPEC) 2017-18     135.500               0.000                102.891        32.609            32.609               0.0             32.609       NaN                   135
#    P001504                                                                                                      100     Rehabilitation/Upgradation and Widening of Quetta - Dhadhar Section of N-65 (118.322 km) 2021-22    7115.760               0.000                  0.000      7115.760          1000.000               0.0           1000.000       NaN                  7115
#    P000555                                                                                                                                                                         100 KW MW Gwadar, Balochistan 2016-17     139.800               0.000                  0.900       139.000            33.804               0.0             33.804    33.804                   139
#    P000696                                                                                                                                                                         100 KW MW Gwadar, Balochistan 2017-18     139.842              26.312                 34.696       105.146            50.000               0.0             50.000       NaN                   139
#    P000898                                                                                                                                                                          100 KW MW Transmitter Gwadar 2018-19     139.842               0.000                101.913        37.929            15.000               0.0             15.000       NaN                   139

# %%
# List of values
numbers = [17369, 22, 912, 319, 111, 1087, 56, 134, 1, 523, 4912, 4912, 4912, 8379,
    2010, 893, 99, 55, 58, 319, 17369, 1087, 95, 134, 287, 42, 303, 20, 127, 4,
    69, 893, 55, 49954, 30, 7708, 1500, 53, 6890, 127, 303, 8624, 63081, 18, 89,
    100, 90, 60, 100, 460, 730, 383, 915, 700, 249, 1246, 100, 27, 718, 190,
    17421, 160, 60, 100, 132, 132, 6878, 14144, 264, 1050, 2937, 400, 475, 8624,
    462, 154, 76486, 4667, 196, 7829, 81582, 81582, 9500, 80352, 28465, 1347,
    839, 200, 196, 7829, 504, 119, 123, 110, 221, 100, 50, 50, 150, 300, 264,
    300, 300, 10, 10, 5000, 10711, 1332, 1332, 4546, 4546, 49, 49, 4546, 450,
    143, 143, 298, 298, 4, 4485, 11458, 6536, 6536, 19188, 20000, 20000, 180,
    180, 180, 227, 200, 200, 200, 1000, 1000, 1209, 1382, 1382, 1382, 1209, 198,
    150, 110, 147, 132, 588, 588, 734, 2010, 1759, 2167, 2010, 2010, 1759, 1759,
    150, 2167, 2167, 2719, 2719, 2719, 2719, 300, 200, 841, 69, 58, 56, 56, 58,
    58, 58, 4751, 39, 475, 184, 184, 954, 4796, 4796, 19188, 19188, 19188, 15,
    15, 57, 57, 504, 504, 13512, 13512, 4647, 4647, 4647, 4647, 2467, 2467, 7829,
    4647, 7829, 6000, 7829, 1591, 1600, 7829, 1591, 1050, 4647, 1591, 1591, 226,
    205, 390, 57, 303, 495, 174, 383, 383, 383, 383, 471, 806, 806, 806, 806,
    466, 961, 700, 700, 700, 700, 761, 1246, 761, 1246, 249, 249, 249, 730, 471,
    39, 45, 39, 45, 50, 55, 20, 58, 2937, 2937, 300, 300, 2937, 298, 298, 167,
    167, 39, 22, 30, 21, 21, 21, 100, 84, 84, 14, 17, 2000, 2000, 31, 36, 57, 21,
    39, 57, 57, 39, 119, 15, 123, 797, 797, 797, 797, 797, 797, 797, 797, 200,
    110, 20000, 10000, 10000, 16, 51, 50, 9636, 9636, 5400, 5400, 9636, 9636,
    400, 400, 13758, 13758, 301, 301, 301, 841, 841, 841, 841, 100, 13758, 13758,
    13758, 841, 841, 120, 50, 841, 403, 50, 335, 335, 335, 184, 400, 89, 89, 89,
    25, 22, 6, 70, 104, 160, 1019, 221, 400, 30, 35, 150, 150, 150, 400, 100, 50,
    50, 100, 100, 100, 950, 2500, 2500, 15, 475, 100, 14061, 14061, 14061, 14061,
    14061, 14061, 21, 21, 5000, 1347, 1347, 834, 834, 834, 890, 890, 890, 1347,
    1347, 1347, 1499, 1499, 1499, 1581, 1298, 1581, 25, 25, 462, 462, 462, 150,
    60, 330, 350, 350, 15, 70, 70, 244, 244, 94, 94, 94, 131, 131, 113, 113, 276,
    276, 4000, 350, 350, 639, 735, 12000, 12000, 60, 9334, 9334, 9334, 3000,
    4667, 4667, 450, 450, 450, 450, 390, 158, 158, 80, 80, 946, 946, 1500, 1500,
    1500, 350, 48, 48, 36, 53, 58, 55, 36, 36, 51, 53, 53, 53, 128, 128, 10, 250,
    250, 123, 123, 32, 50, 58, 100, 58, 50, 50, 41, 41, 4000, 350, 123, 5, 9488,
    6314, 6400, 252, 5, 59, 325, 474, 474, 474, 289, 289, 289, 510, 510, 510,
    6544, 6544, 6544, 6544, 4751, 4751, 21, 25, 150, 15, 1000, 1000, 1000, 46,
    46, 60, 60, 80, 80, 200, 200, 57, 180, 24, 24, 200, 10, 30, 196, 15, 226, 500,
    222, 222, 222, 11500, 15230, 15230, 8379, 8379, 200, 843, 843, 843, 48, 53,
    41, 3000, 4796, 4795, 4795, 4795, 90, 154, 27, 27, 77, 1695, 421, 2185, 2381,
    835, 835, 2381, 2381, 1000, 974, 974, 974, 974, 974, 300, 300, 300, 300, 971,
    971, 971, 480, 480, 1000, 1000, 1000, 1000, 1000, 1200, 823, 200, 200, 76486,
    76486, 76486, 90500, 90500, 6982, 34, 344, 344, 718, 718, 718, 718, 718, 718,
    718, 38, 287, 38, 56, 56, 56, 59, 500, 1554, 1512, 500, 519, 400, 400, 400,
    519, 853, 853, 853, 56, 56, 56, 95, 300, 300, 500, 400, 104, 104, 104, 200,
    39, 70, 48, 120, 53, 53, 53, 59, 56, 174, 174, 279, 287, 287, 58, 58, 58, 59,
    59, 300, 55, 1958, 190, 189, 189, 853, 853, 46, 46, 46, 46, 371, 408, 670,
    371, 371, 477, 477, 1503, 1507, 1260, 1266, 1503, 1260, 2820, 1518, 1518,
    1518, 1518, 1518, 1518, 1500, 550, 550, 550, 1500, 550, 1580, 1580, 2820,
    2820, 2820, 500, 174, 174, 279, 1518, 560, 60, 56, 42, 42, 56, 56, 42, 56,
    56, 56, 35, 2500, 2500, 2500, 1500, 5769, 2370, 2370, 5769, 2370, 1500, 56,
    80, 52, 61, 61, 67, 10, 10, 147, 67, 80, 315, 20, 315, 315, 315, 315, 5, 5,
    3000, 100, 315, 500, 500, 2500, 10511, 9500, 2500, 58, 58, 17000, 17000, 90,
    90, 23168, 23168, 23168, 23168, 23168, 25000, 25000, 25000, 25000, 25000,
    25000, 25000, 1475, 1475, 1475, 1475, 2269, 2269, 59, 1500, 5000, 1412, 3000,
    3000, 51, 52, 592, 592, 592, 592, 3450, 3450, 3450, 5400, 78, 78, 78, 78, 77,
    77, 35, 35, 120, 120, 120, 36, 500, 22, 20, 5, 21, 58, 48, 48, 48, 48, 17421,
    3685, 14070, 17421, 57562, 57562, 59352, 80352, 80352, 80352, 80352, 22921,
    22921, 80352, 9327, 19140, 6671, 19140, 19140, 16, 2500, 300, 300, 16000,
    16000, 58, 17, 457, 1000, 457, 217, 217, 217, 250, 250, 480, 450, 3138, 3138,
    3138, 3138, 3138, 3138, 18, 2718, 2718, 2718, 505, 2718, 505, 505, 0, 1000,
    49954, 49954, 49954, 49954, 49954, 49954, 18027, 18027, 28465, 18027, 18027,
    18027, 26460, 18027, 11396, 11396, 11396, 12000, 11396, 11396, 8540, 8540,
    8540, 8540, 7675, 22247, 22947, 7675, 22247, 22247, 22247, 22247
]


# Extracting unique values while preserving the order
unique_values = []
for num in numbers:
    if num not in unique_values:
        unique_values.append(num)

# Number of unique values
num_unique_values = len(unique_values)

print("Unique values:", unique_values)
print("Number of unique values:", num_unique_values)
# Out:
# Unique values: [17369, 22, 912, 319, 111, 1087, 56, 134, 1, 523, 4912, 8379, 2010, 893, 99, 55, 58, 95, 287, 42, 303, 20, 127, 4, 69, 49954, 30, 7708, 1500, 53, 6890, 8624, 63081, 18, 89, 100, 90, 60, 460, 730, 383, 915, 700, 249, 1246, 27, 718, 190, 17421, 160, 132, 6878, 14144, 264, 1050, 2937, 400, 475, 462, 154, 76486, 4667, 196, 7829, 81582, 9500, 80352, 28465, 1347, 839, 200, 504, 119, 123, 110, 221, 50, 150, 300, 10, 5000, 10711, 1332, 4546, 49, 450, 143, 298, 4485, 11458, 6536, 19188, 20000, 180, 227, 1000, 1209, 1382, 198, 147, 588, 734, 1759, 2167, 2719, 841, 4751, 39, 184, 954, 4796, 15, 57, 13512, 4647, 2467, 6000, 1591, 1600, 226, 205, 390, 495, 174, 471, 806, 466, 961, 761, 45, 167, 21, 84, 14, 17, 2000, 31, 36, 797, 10000, 16, 51, 9636, 5400, 13758, 301, 120, 403, 335, 25, 6, 70, 104, 1019, 35, 950, 2500, 14061, 834, 890, 1499, 1581, 1298, 330, 350, 244, 94, 131, 113, 276, 4000, 639, 735, 12000, 9334, 3000, 158, 80, 946, 48, 128, 250, 32, 41, 5, 9488, 6314, 6400, 252, 59, 325, 474, 289, 510, 6544, 46, 24, 500, 222, 11500, 15230, 843, 4795, 77, 1695, 421, 2185, 2381, 835, 974, 971, 480, 1200, 823, 90500, 6982, 34, 344, 38, 1554, 1512, 519, 853, 279, 1958, 189, 371, 408, 670, 477, 1503, 1507, 1260, 1266, 2820, 1518, 550, 1580, 560, 5769, 2370, 52, 61, 67, 315, 10511, 17000, 23168, 25000, 1475, 2269, 1412, 592, 3450, 78, 3685, 14070, 57562, 59352, 22921, 9327, 19140, 6671, 16000, 457, 217, 3138, 2718, 505, 0, 18027, 26460, 11396, 8540, 7675, 22247, 22947]
# Number of unique values: 277

# %%
numbers = [22947]

# Get the total number of values in the list
total_numbers = len(numbers)

print("Total numbers in the list:", total_numbers)
# Out:
# Total numbers in the list: 6

# %%
numbers = [
    561.116,
    425.583,
    625.583,
    312.127,
    2900,
    565,
    2675,
    1100,
    1450,
    6035.26,
    2400,
    1906.8,
    2100.544,
    555,
    1800,
    519,
    1144.995,
    1250,
    7000,
    350,
    1200,
    1050,
    555.589,
    4700,
    3250,
    913.92,
    920.64,
    2705,
    1600,
    7500,
    80,
    450,
    600,
    750,
    700,
    250,
    3300,
    300,
    900,
    800,
    400,
    50,
    2500,
    2000,
    100,
    500,
    1500,
    1000,
    3000,
    5000,
    4.092,
    8.871,
    3.043,
    19.658,
    11.424,
    4.711,
    0.717,
    17.904,
    14.93,
    7.35,
    19.8,
    27.197,
    2.668,
    13.49,
    13.491,
    18.295,
    10.553,
    6.524,
    28.4,
    31.26,
    19.464,
    30.224,
    19.993,
    13.15,
    16.078,
    28.917,
    7.068,
    22.737,
    11.615,
    6.614,
    7.977,
    7.72,
    17.08,
    14.475,
    19.663,
    7.197,
    49.036,
    19.236,
    20.09,
    36.446,
    3.109,
    14.609,
    8.992,
    31.708,
    13.488,
    29.156,
    19.592,
    25.412,
    25.312,
    14.43,
    34.521,
    26.9,
    10.367,
    38.463,
    8.578,
    28.783,
    38.783,
    19.335,
    26.5,
    27.07,
    44.437,
    5.279,
    15.913,
    22.5,
    13.199,
    23.965,
    52.28,
    44.999,
    24.35,
    9.68,
    18.91,
    24,
    13.37,
    92.324,
    103,
    30.939,
    23.55,
    33.3,
    57.264,
    31.975,
    20.461,
    32.609,
    40.146,
    10.708,
    72.295,
    39,
    85,
    41.4,
    35.251,
    81,
    37.581,
    72.382,
    22.15,
    129.477,
    76.567,
    18.255,
    28.996,
    77.65,
    168,
    155,
    115,
    95,
    6.4,
    67.422,
    42.614,
    20.182,
    23.068,
    117.014,
    114.341,
    91.473,
    201.2,
    122.625,
    24.889,
    164.539,
    88.704,
    85.01,
    163.368,
    240,
    106.5,
    75.437,
    45.257,
    143.446,
    100.63,
    61.42,
    159.65,
    135.013,
    57.8,
    183.41,
    72,
    185.69,
    137.5,
    84,
    6,
    233.311,
    311.436,
    139.987,
    53.125,
    183.81,
    161.099,
    16.204,
    153.595,
    204,
    171.807,
    219,
    94,
    186,
    275.36,
    72.825,
    305.904,
    136.4,
    22.863,
    249.054,
    399.623,
    194.4,
    160.14,
    147,
    343,
    110.871,
    211.736,
    209,
    366.921,
    91.638,
    390.558,
    85.164,
    139.75,
    384.042,
    133.114,
    270,
    245,
    191,
    150.757,
    260.731,
    123.143,
    102.729,
    452.729,
    215,
    85.852,
    378.91,
    190.365,
    80.384,
    238.545,
    547.48,
    547.84,
    49.64,
    260.659,
    664.309,
    265.239,
    408.279,
    128.152,
    19.14,
    198,
    396,
    145.218,
    124.862,
    183.12,
    195,
    304.95,
    376.274,
    356.527,
    62.086,
    248.346,
    632.605,
    312.734,
    349.647,
    165.433,
    6.465,
    386.184,
    264.302,
    882,
    138.2,
    138.202,
    34.409,
    41.462,
    312.808,
    172.044,
    562.057,
    631.232,
    308.865,
    237.889,
    119.709,
    275,
    439.856,
    82.019,
    225,
    710.215,
    325,
    175,
    682.784,
    1235,
    292.3,
    254.25,
    329.237,
    214.49,
    650,
    669.49,
    212.517,
    320,
    274,
    475,
    255,
    9.783,
    1140.09,
    593.19,
    1797.039,
    560.924,
    1955.416,
    227.848,
    1163.724,
    793.053,
    468.053,
    691.13,
    76.56,
    1968.48,
    1345,
    2600,
    4400,
    6604.803,
    1860,
    66,
    366,
    38.509,
    210,
    6000,
    2.979,
    7.054,
    4.448,
    17.357,
    4.494,
    17.378,
    12.684,
    0.27,
    22.973,
    28.722,
    10.099,
    8.522,
    16.6,
    11.41,
    6.9,
    57.345,
    66.93,
    55.567,
    87.166,
    77.667,
    53,
    4.6,
    154.921,
    147.735,
    324.452,
    73.502,
    52.64,
    28.501,
    106,
    114,
    172.265,
    386.483,
    160,
    64.318,
    1083.49,
    1170,
    1320,
    3433,
    5235,
    3.684,
    3.486,
    3.135,
    19.754,
    25.488,
    20.875,
    16.254,
    20.78,
    25.006,
    27.818,
    30.569,
    17.32,
    7.74,
    35.74,
    15.562,
    34.112,
    16.796,
    43.555,
    3.988,
    3.618,
    26.331,
    4.897,
    9.592,
    35.593,
    21.273,
    36.423,
    21.434,
    26.444,
    26.644,
    7,
    12,
    33.2,
    22,
    80.5,
    33.804,
    25.35,
    42.25,
    84.21,
    32.384,
    13.955,
    26.683,
    260.46,
    169.318,
    42.626,
    24.609,
    7.153,
    179.21,
    130.422,
    358.171,
    146.307,
    41.475,
    190,
    408.816,
    134.752,
    216.816,
    327,
    152.672,
    234.016,
    403.12,
    355,
    413.4,
    240.721,
    427.721,
    240.739,
    675,
    805.736,
    770,
    836.37,
    1300,
    4500,
    2800,
    4631.543,
    11315,
    135,
    76,
    32.484,
    0.945,
    21.31,
    30.828,
    44,
    27.621,
    57.5,
    58,
    0.222,
    94.425,
    196,
    31.616,
    230,
    303,
    850,
    12.385,
    984,
    15000,
    1.26,
    1.429,
    2.385,
    4.5,
    5.611,
    5.633,
    3,
    4,
    8.968,
    9.522,
    10.08,
    10.712,
    11.085,
    12.176,
    13.5,
    13.978,
    14.35,
    16,
    11.286,
    17.55,
    8,
    18,
    9,
    18.897,
    20.59,
    21.35,
    21.983,
    22.248,
    11,
    25.574,
    27.35,
    27.981,
    32.813,
    33.999,
    17,
    35.214,
    24.023,
    49.996,
    49.997,
    50.04,
    52.339,
    55.312,
    55.537,
    38,
    17.586,
    55.822,
    56.5,
    28.25,
    56.65,
    14,
    57.7,
    58.12,
    47.36,
    58.708,
    58.8,
    17.28,
    69.37,
    71.324,
    72.6,
    83.977,
    84.43,
    45,
    93,
    99.188,
    60,
    107.943,
    55,
    111.376,
    111.45,
    112.318,
    113.418,
    26,
    132,
    147.17,
    64,
    154.777,
    192.168,
    65,
    149.77,
    130,
    140,
    287.54,
    273.899,
    77.96,
    295,
    75,
    30,
    319.3,
    112.124,
    354,
    70,
    90,
    120,
    232.725,
    223.72,
    499.849,
    22.7,
    507.477,
    20,
    207,
    15,
    191.7,
    731.447,
    180,
    40,
    421,
    211.291,
    5,
    110,
    25,
    10,
    185,
    367.61,
    345,
    35,
    196.128,
    470,
    610.698,
    550,
    125,
    150,
    200,
    172.7,
    4546,
    1116.961,
    1,
    458,
    1700,
    895.853,
    4000,
    8000,
    0,
    10000,
    2820
]

total = sum(numbers)
print(total)
# Out:
# 267498.4299999998

# %%
numbers = [
    561.116, 425.583, 625.583, 312.127, 2900, 565, 2675, 1100, 1450, 6035.26,
    2400, 1906.8, 2100.544, 555, 1800, 519, 1144.995, 1250, 7000, 350,
    1200, 1050, 555.589, 4700, 3250, 913.92, 920.64, 2705, 1600, 7500,
    80, 450, 600, 750, 700, 250, 3300, 300, 900, 800, 400, 50,
    2500, 2000, 100, 500, 1500, 1000, 3000, 5000,
    4.092, 8.871, 3.043, 19.658, 11.424, 4.711, 0.717, 17.904, 14.93,
    7.35, 19.8, 27.197, 2.668, 13.49, 13.491, 18.295, 10.553, 6.524,
    28.4, 31.26, 19.464, 30.224, 19.993, 13.15, 16.078, 28.917, 7.068,
    22.737, 11.615, 6.614, 7.977, 7.72, 17.08, 14.475, 19.663, 7.197,
    49.036, 19.236, 20.09, 36.446, 3.109, 14.609, 8.992, 31.708, 13.488,
    29.156, 19.592, 25.412, 25.312, 14.43, 34.521, 26.9, 10.367, 38.463,
    8.578, 28.783, 38.783, 19.335, 26.5, 27.07, 44.437, 5.279, 15.913,
    22.5, 13.199, 23.965, 52.28, 44.999, 24.35, 9.68, 18.91, 24, 13.37,
    92.324, 103, 30.939, 23.55, 33.3, 57.264, 31.975, 20.461, 32.609,
    40.146, 10.708, 72.295, 39, 85, 41.4, 35.251, 81, 37.581, 72.382,
    22.15, 129.477, 76.567, 18.255, 28.996, 77.65, 168, 155, 115, 95,
    6.4, 67.422, 42.614, 20.182, 23.068, 117.014, 114.341, 91.473,
    201.2, 122.625, 24.889, 164.539, 88.704, 85.01, 163.368, 240, 106.5,
    75.437, 45.257, 143.446, 100.63, 61.42, 159.65, 135.013, 57.8,
    183.41, 72, 185.69, 137.5, 84, 6, 233.311, 311.436, 139.987, 53.125,
    183.81, 161.099, 16.204, 153.595, 204, 171.807, 219, 94, 186,
    275.36, 72.825, 305.904, 136.4, 22.863, 249.054, 399.623, 194.4,
    160.14, 147, 343, 110.871, 211.736, 209, 366.921, 91.638, 390.558,
    85.164, 139.75, 384.042, 133.114, 270, 245, 191, 150.757, 260.731,
    123.143, 102.729, 452.729, 215, 85.852, 378.91, 190.365, 80.384,
    238.545, 547.48, 547.84, 49.64, 260.659, 664.309, 265.239, 408.279,
    128.152, 19.14, 198, 396, 145.218, 124.862, 183.12, 195, 304.95,
    376.274, 356.527, 62.086, 248.346, 632.605, 312.734, 349.647, 165.433,
    6.465, 386.184, 264.302, 882, 138.2, 138.202, 34.409, 41.462,
    312.808, 172.044, 562.057, 631.232, 308.865, 237.889, 119.709, 275,
    439.856, 82.019, 225, 710.215, 325, 175, 682.784, 1235, 292.3,
    254.25, 329.237, 214.49, 650, 669.49, 212.517, 320, 274, 475, 255,
    9.783, 1140.09, 593.19, 1797.039, 560.924, 1955.416, 227.848, 1163.724,
    793.053, 468.053, 691.13, 76.56, 1968.48, 1345, 2600, 4400, 6604.803,
    1860, 66, 366, 38.509, 210, 6000, 2.979, 7.054, 4.448, 17.357, 4.494,
    17.378, 12.684, 0.27, 22.973, 28.722, 10.099, 8.522, 16.6, 11.41,
    6.9, 57.345, 66.93, 55.567, 87.166, 77.667, 53, 4.6, 154.921,
    147.735, 324.452, 73.502, 52.64, 28.501, 106, 114, 172.265, 386.483,
    160, 64.318, 1083.49, 1170, 1320, 3433, 5235, 3.684, 3.486, 3.135,
    19.754, 25.488, 20.875, 16.254, 20.78, 25.006, 27.818, 30.569, 17.32,
    7.74, 35.74, 15.562, 34.112, 16.796, 43.555, 3.988, 3.618, 26.331,
    4.897, 9.592, 35.593, 21.273, 36.423, 21.434, 26.444, 26.644, 7, 12,
    33.2, 22, 80.5, 33.804, 25.35, 42.25, 84.21, 32.384, 13.955, 26.683,
    260.46, 169.318, 42.626, 24.609, 7.153, 179.21, 130.422, 358.171,
    146.307, 41.475, 190, 408.816, 134.752, 216.816, 327, 152.672, 234.016,
    403.12, 355, 413.4, 240.721, 427.721, 240.739, 675, 805.736, 770,
    836.37, 1300, 4500, 2800, 4631.543, 11315, 135, 76, 32.484, 0.945,
    21.31, 30.828, 44, 27.621, 57.5, 58, 0.222, 94.425, 196, 31.616,
    230, 303, 850, 12.385, 984, 15000, 1.26, 1.429, 2.385, 4.5, 5.611,
    5.633, 3, 4, 8.968, 9.522, 10.08, 10.712, 11.085, 12.176, 13.5,
    13.978, 14.35, 16, 11.286, 17.55, 8, 18, 9, 18.897, 20.59, 21.35,
    21.983, 22.248, 11, 25.574, 27.35, 27.981, 32.813, 33.999, 17,
    35.214, 24.023, 49.996, 49.997, 50.04, 52.339, 55.312, 55.537, 38,
    17.586, 55.822, 56.5, 28.25, 56.65, 14, 57.7, 58.12, 47.36, 58.708,
    58.8, 17.28, 69.37, 71.324, 72.6, 83.977, 84.43, 45, 93, 99.188,
    60, 107.943, 55, 111.376, 111.45, 112.318, 113.418, 26, 132,
    147.17, 64, 154.777, 192.168, 65, 149.77, 130, 140, 287.54, 273.899,
    77.96, 295, 75, 30, 319.3, 112.124, 354, 70, 90, 120, 232.725,
    223.72, 499.849, 22.7, 507.477, 20, 207, 15, 191.7, 731.447, 180,
    40, 421, 211.291, 5, 110, 25, 10, 185, 367.61, 345, 35, 196.128,
    470, 610.698, 550, 125, 150, 200, 172.7, 4546, 1116.961, 1, 458,
    1700, 895.853, 4000, 8000, 0, 10000, 2820
]

total = sum(numbers)
print(total)
# Out:
# 267498.4299999998
